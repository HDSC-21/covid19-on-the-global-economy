# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pandas_profiling import ProfileReport
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-23-19efdb25f55a> in <module>
#       3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
# ----> 5 from pandas_profiling import ProfileReport
#
# ModuleNotFoundError: No module named 'pandas_profiling'

# %%
data_daily = pd.read_csv('https://raw.githubusercontent.com/HDSC-21/covid19-on-the-global-economy/main/Source/worldometer_coronavirus_daily_data.csv')
data = pd.read_csv('https://raw.githubusercontent.com/HDSC-21/covid19-on-the-global-economy/main/Source/worldometer_coronavirus_summary_data.csv')

# %%
data.head(-30)
# Out:
#                 country continent  total_confirmed  total_deaths  \
# 0           Afghanistan      Asia           147473        6736.0
# 1               Albania    Europe           133081        2457.0
# 2               Algeria    Africa           171392        4254.0
# 3               Andorra    Europe            14678         128.0
# 4                Angola    Africa            42646        1008.0
# ..                  ...       ...              ...           ...
# 185         South Sudan    Africa            11049         119.0
# 186               Spain    Europe          4447044       81486.0
# 187           Sri Lanka      Asia           308812        4436.0
# 188  State Of Palestine      Asia           316738        3603.0
# 189               Sudan    Africa            37138        2776.0
#
#      total_recovered  active_cases  serious_or_critical  \
# 0            98073.0       42664.0               1124.0
# 1           130222.0         402.0                  3.0
# ...

# %%
data_daily.head()
# Out:
#         date      country  cumulative_total_cases  daily_new_cases  \
# 0  2020-2-15  Afghanistan                     0.0              NaN
# 1  2020-2-16  Afghanistan                     0.0              NaN
# 2  2020-2-17  Afghanistan                     0.0              NaN
# 3  2020-2-18  Afghanistan                     0.0              NaN
# 4  2020-2-19  Afghanistan                     0.0              NaN
#
#    active_cases  cumulative_total_deaths  daily_new_deaths
# 0           0.0                      0.0               NaN
# 1           0.0                      0.0               NaN
# 2           0.0                      0.0               NaN
# 3           0.0                      0.0               NaN
# 4           0.0                      0.0               NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   country                         220 non-null    object
#  1   continent                       220 non-null    object
#  2   total_confirmed                 220 non-null    int64
#  3   total_deaths                    207 non-null    float64
#  4   total_recovered                 219 non-null    float64
#  5   active_cases                    219 non-null    float64
#  6   serious_or_critical             146 non-null    float64
#  7   total_cases_per_1m_population   220 non-null    int64
#  8   total_deaths_per_1m_population  204 non-null    float64
#  9   total_tests                     210 non-null    float64
#  10  total_tests_per_1m_population   210 non-null    float64
#  11  population                      220 non-null    int64
# ...

# %%
data.shape
# Out:
# (220, 12)

# %%
data.isnull().sum()
# Out:
# country                            0
# continent                          0
# total_confirmed                    0
# total_deaths                      13
# total_recovered                    1
# active_cases                       1
# serious_or_critical               74
# total_cases_per_1m_population      0
# total_deaths_per_1m_population    16
# total_tests                       10
# total_tests_per_1m_population     10
# population                         0
# dtype: int64

# %%
data.country.unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua And Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bosnia And Herzegovina',
#        'Botswana', 'Brazil', 'British Virgin Islands',
#        'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi',
#        'Cabo Verde', 'Cambodia', 'Cameroon', 'Canada',
#        'Caribbean Netherlands', 'Cayman Islands',
#        'Central African Republic', 'Chad', 'Channel Islands', 'Chile',
#        'China Hong Kong Sar', 'China Macao Sar', 'China', 'Colombia',
#        'Comoros', 'Congo', 'Costa Rica', 'Cote D Ivoire', 'Croatia',
#        'Cuba', 'Curacao', 'Cyprus', 'Czech Republic',
#        'Democratic Republic Of The Congo', 'Denmark', 'Djibouti',
#        'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
# ...

# %%
data.continent.unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'North America', 'South America',
#        'Australia/Oceania'], dtype=object)

# %%
np.around(data.describe())
# Out:
#        total_confirmed  total_deaths  total_recovered  active_cases  \
# count            220.0         207.0            219.0         219.0
# mean          902192.0       20444.0         810619.0       67634.0
# std          3598470.0       71537.0        3251487.0      386898.0
# min                1.0           1.0              1.0       -1489.0
# 25%             7896.0         150.0           5355.0         406.0
# 50%            77338.0        1375.0          62863.0        3488.0
# 75%           409994.0        8072.0         380964.0       20766.0
# max         35733967.0      629290.0       30812873.0     5438593.0
#
#        serious_or_critical  total_cases_per_1m_population  \
# count                146.0                          220.0
# mean                 602.0                        39901.0
# std                 1625.0                        42102.0
# min                    1.0                            9.0
# 25%                    9.0                         3090.0
# ...

# %%
from pandas_profiling import ProfileReport
report = ProfileReport(data)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-22-3dbb49f8ab02> in <module>
# ----> 1 from pandas_profiling import ProfileReport
#       2 report = ProfileReport(data)
#
# ModuleNotFoundError: No module named 'pandas_profiling'

# %%
print(data['active_cases'].describe())
print(data['cumulative_total_deaths'].describe())
print(data['daily_new_deaths'].describe())
